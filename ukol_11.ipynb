# %%
import pandas as pd
platy = pd.read_csv("platy_2021_02.csv")
platy.head()
# Out:
#    cislo_zamestnance     plat
# 0                  3  54900.0
# 1                  6  54800.0
# 2                  7  36400.0
# 3                  8  47900.0
# 4                 16  34200.0

# %%
platy["plat"].hist()
# Out:
# <Axes: >

# %%
platy["plat"].hist(bins=[35000, 35000, 40000, 50000, 55000, 60000])
# Out:
# <Axes: >
